# %%
import pandas as pd

# %%
df=pd.read_excel('Customer Demographic.xlsx')

# %%
df.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                        customer_id
# 1                                                1.0
# 2                                                2.0
# 3                                                3.0
# 4                                                4.0
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3                           Unnamed: 4  \
# 0  first_name  last_name     gender  past_3_years_bike_related_purchases
# 1     Laraine  Medendorp          F                                 93.0
# 2         Eli    Bockman       Male                                 81.0
# 3       Arlin     Dearle       Male                                 61.0
# 4      Talbot        NaN       Male                                 33.0
#
#             Unnamed: 5              Unnamed: 6             Unnamed: 7  \
# ...

# %%
df.columns=df.iloc[0]#writing header names

# %%
df.head()
# Out:
# 0  customer_id  first_name  last_name  gender  \
# 0  customer_id  first_name  last_name  gender
# 1          1.0     Laraine  Medendorp       F
# 2          2.0         Eli    Bockman    Male
# 3          3.0       Arlin     Dearle    Male
# 4          4.0      Talbot        NaN    Male
#
# 0  past_3_years_bike_related_purchases                  DOB  \
# 0  past_3_years_bike_related_purchases                  DOB
# 1                                 93.0  1953-10-12 00:00:00
# 2                                 81.0  1980-12-16 00:00:00
# 3                                 61.0  1954-01-20 00:00:00
# 4                                 33.0  1961-10-03 00:00:00
#
# 0               job_title  job_industry_category  wealth_segment  \
# 0               job_title  job_industry_category  wealth_segment
# 1     Executive Secretary                 Health   Mass Customer
# 2  Administrative Officer     Financial Services   Mass Customer
# ...

# %%
df.drop(0,axis=0,inplace=True)#removing extra header column

# %%
df.head()
# Out:
# 0 customer_id      first_name  last_name  gender  \
# 1         1.0         Laraine  Medendorp       F
# 2         2.0             Eli    Bockman    Male
# 3         3.0           Arlin     Dearle    Male
# 4         4.0          Talbot        NaN    Male
# 5         5.0  Sheila-kathryn     Calton  Female
#
# 0 past_3_years_bike_related_purchases                  DOB  \
# 1                                93.0  1953-10-12 00:00:00
# 2                                81.0  1980-12-16 00:00:00
# 3                                61.0  1954-01-20 00:00:00
# 4                                33.0  1961-10-03 00:00:00
# 5                                56.0  1977-05-13 00:00:00
#
# 0               job_title job_industry_category     wealth_segment  \
# 1     Executive Secretary                Health      Mass Customer
# 2  Administrative Officer    Financial Services      Mass Customer
# 3      Recruiting Manager              Property      Mass Customer
# ...

# %%
df.shape
# Out:
# (4000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 1 to 4000
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   object
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   object
#  5   DOB                                  3913 non-null   object
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
df['gender'].unique()
# Out:
# array(['F', 'Male', 'Female', 'U', 'Femal', 'M'], dtype=object)

# %%
import numpy as np
gender={'Female':'F','Male':'M','U':np.nan,'Femal':'F','M':'M','F':'F'}
df['gender']=df['gender'].map(gender)#using only F and M for gender

# %%
df.drop('default',axis=1,inplace=True)#removing default folder as its purpose not known

# %%
df.head()
# Out:
# 0 customer_id      first_name  last_name gender  \
# 1         1.0         Laraine  Medendorp      F
# 2         2.0             Eli    Bockman      M
# 3         3.0           Arlin     Dearle      M
# 4         4.0          Talbot        NaN      M
# 5         5.0  Sheila-kathryn     Calton      F
#
# 0 past_3_years_bike_related_purchases                  DOB  \
# 1                                93.0  1953-10-12 00:00:00
# 2                                81.0  1980-12-16 00:00:00
# 3                                61.0  1954-01-20 00:00:00
# 4                                33.0  1961-10-03 00:00:00
# 5                                56.0  1977-05-13 00:00:00
#
# 0               job_title job_industry_category     wealth_segment  \
# 1     Executive Secretary                Health      Mass Customer
# 2  Administrative Officer    Financial Services      Mass Customer
# 3      Recruiting Manager              Property      Mass Customer
# ...

# %%
df.describe()
# Out:
# 0       customer_id first_name last_name gender  \
# count        4000.0       4000      3875   3912
# unique       4000.0       3139      3725      2
# top             1.0        Max  Pristnor      F
# freq            1.0          5         3   2039
#
# 0       past_3_years_bike_related_purchases                  DOB  \
# count                                4000.0                 3913
# unique                                100.0                 3448
# top                                    16.0  1978-01-30 00:00:00
# freq                                   56.0                    7
#
# 0                                  job_title job_industry_category  \
# count                                   3494                  3344
# unique                                   195                     9
# top     Business Systems Development Analyst         Manufacturing
# freq                                      45                   799
#
# ...

# %%
df['tenure']=df['tenure'].astype('float')

# %%
df['past_3_years_bike_related_purchases']=df['past_3_years_bike_related_purchases'].astype('float')

# %%
#changed datatypes of certain fields from categorical to numeric

# %%
df.describe()
# Out:
# 0      past_3_years_bike_related_purchases       tenure
# count                          4000.000000  3913.000000
# mean                             48.890000    10.657041
# std                              28.715005     5.660146
# min                               0.000000     1.000000
# 25%                              24.000000     6.000000
# 50%                              48.000000    11.000000
# 75%                              73.000000    15.000000
# max                              99.000000    22.000000

# %%
df.nunique()
# Out:
# 0
# customer_id                            4000
# first_name                             3139
# last_name                              3725
# gender                                    2
# past_3_years_bike_related_purchases     100
# DOB                                    3448
# job_title                               195
# job_industry_category                     9
# wealth_segment                            3
# deceased_indicator                        2
# owns_car                                  2
# tenure                                   22
# dtype: int64

# %%
df['job_industry_category'].unique()
# Out:
# array(['Health', 'Financial Services', 'Property', 'IT', nan, 'Retail',
#        'Argiculture', 'Manufacturing', 'Telecommunications',
#        'Entertainment'], dtype=object)

# %%
df['deceased_indicator'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df['wealth_segment'].unique()
# Out:
# array(['Mass Customer', 'Affluent Customer', 'High Net Worth'],
#       dtype=object)

# %%
df['owns_car'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['DOB']=pd.to_datetime(df['DOB'])

# %%
df['DOB'].max()
# Out:
# Timestamp('2002-03-11 00:00:00')

# %%
df['DOB'].min()
# Out:
# Timestamp('1843-12-21 00:00:00')

# %%
df['year']=df['DOB'].dt.year

# %%
df_values=df[df['year']<1900].index

# %%
df_values.shape
# Out:
# (1,)

# %%
df.drop(df_values,axis=0,inplace=True)

# %%
#removed a row which has age as 175 years

# %%
df.reset_index()
# Out:
# 0     index customer_id      first_name  last_name gender  \
# 0         1         1.0         Laraine  Medendorp      F
# 1         2         2.0             Eli    Bockman      M
# 2         3         3.0           Arlin     Dearle      M
# 3         4         4.0          Talbot        NaN      M
# 4         5         5.0  Sheila-kathryn     Calton      F
# ...     ...         ...             ...        ...    ...
# 3994   3996      3996.0         Rosalia   Halgarth      F
# 3995   3997      3997.0          Blanch     Nisuis      F
# 3996   3998      3998.0          Sarene    Woolley    NaN
# 3997   3999      3999.0       Patrizius        NaN      M
# 3998   4000      4000.0           Kippy    Oldland      M
#
# 0     past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                    93.0 1953-10-12     Executive Secretary
# 1                                    81.0 1980-12-16  Administrative Officer
# ...

# %%
df.to_excel('Customer Demographic_cleaned.xlsx',index=False)
