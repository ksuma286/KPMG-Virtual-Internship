# %%
import pandas as pd

# %%
df=pd.read_excel('Transactions dataset.xlsx')

# %%
df.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                     transaction_id
# 1                                                1.0
# 2                                                2.0
# 3                                                3.0
# 4                                                4.0
#
#    Unnamed: 1   Unnamed: 2           Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 0  product_id  customer_id     transaction_date  online_order  order_status
# 1         2.0       2950.0  2017-02-25 00:00:00         False      Approved
# 2         3.0       3120.0  2017-05-21 00:00:00          True      Approved
# 3        37.0        402.0  2017-10-16 00:00:00         False      Approved
# 4        88.0       3135.0  2017-08-31 00:00:00         False      Approved
#
# ...

# %%
df.columns=df.iloc[0]#making header

# %%
df.head()
# Out:
# 0  transaction_id  product_id  customer_id     transaction_date  online_order  \
# 0  transaction_id  product_id  customer_id     transaction_date  online_order
# 1             1.0         2.0       2950.0  2017-02-25 00:00:00         False
# 2             2.0         3.0       3120.0  2017-05-21 00:00:00          True
# 3             3.0        37.0        402.0  2017-10-16 00:00:00         False
# 4             4.0        88.0       3135.0  2017-08-31 00:00:00         False
#
# 0  order_status           brand  product_line  product_class  product_size  \
# 0  order_status           brand  product_line  product_class  product_size
# 1      Approved           Solex      Standard         medium        medium
# 2      Approved   Trek Bicycles      Standard         medium         large
# 3      Approved      OHM Cycles      Standard            low        medium
# 4      Approved  Norco Bicycles      Standard         medium        medium
#
# ...

# %%
df.drop(0,axis=0,inplace=True)#removing extra header

# %%
df.head()
# Out:
# 0 transaction_id product_id customer_id     transaction_date online_order  \
# 1            1.0        2.0      2950.0  2017-02-25 00:00:00        False
# 2            2.0        3.0      3120.0  2017-05-21 00:00:00         True
# 3            3.0       37.0       402.0  2017-10-16 00:00:00        False
# 4            4.0       88.0      3135.0  2017-08-31 00:00:00        False
# 5            5.0       78.0       787.0  2017-10-01 00:00:00         True
#
# 0 order_status           brand product_line product_class product_size  \
# 1     Approved           Solex     Standard        medium       medium
# 2     Approved   Trek Bicycles     Standard        medium        large
# 3     Approved      OHM Cycles     Standard           low       medium
# 4     Approved  Norco Bicycles     Standard        medium       medium
# 5     Approved  Giant Bicycles     Standard        medium        large
#
# 0 list_price standard_cost product_first_sold_date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 1 to 20000
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  object
#  1   product_id               20000 non-null  object
#  2   customer_id              20000 non-null  object
#  3   transaction_date         20000 non-null  object
#  4   online_order             19640 non-null  object
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  object
#  11  standard_cost            19803 non-null  object
#  12  product_first_sold_date  19803 non-null  object
# dtypes: object(13)
# memory usage: 2.1+ MB

# %%
df.shape
# Out:
# (20000, 13)

# %%
df.isnull().sum()
# Out:
# 0
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
df.nunique()
# Out:
# 0
# transaction_id             20000
# product_id                   101
# customer_id                 3494
# transaction_date             364
# online_order                   2
# order_status                   2
# brand                          6
# product_line                   4
# product_class                  3
# product_size                   3
# list_price                   296
# standard_cost                103
# product_first_sold_date      100
# dtype: int64

# %%
df['transaction_date']=pd.to_datetime(df['transaction_date'])

# %%
df['list_price']=df['list_price'].astype('float')

# %%
df['standard_cost']=df['standard_cost'].astype('float')

# %%
df.describe()
# Out:
# 0        list_price  standard_cost
# count  20000.000000   19803.000000
# mean    1107.829449     556.046951
# std      582.825242     405.955660
# min       12.010000       7.210000
# 25%      575.270000     215.140000
# 50%     1163.890000     507.580000
# 75%     1635.300000     795.100000
# max     2091.470000    1759.850000

# %%
df.describe(include='object')
# Out:
# 0       transaction_id  product_id  customer_id online_order order_status  \
# count          20000.0     20000.0      20000.0        19640        20000
# unique         20000.0       101.0       3494.0            2            2
# top                1.0         0.0       2183.0         True     Approved
# freq               1.0      1378.0         14.0         9829        19821
#
# 0       brand product_line product_class product_size  product_first_sold_date
# count   19803        19803         19803        19803                  19803.0
# unique      6            4             3            3                    100.0
# top     Solex     Standard        medium       medium                  33879.0
# freq     4253        14176         13826        12990                    234.0

# %%
df['product_id'].nunique()
# Out:
# 101

# %%
df['transaction_date'].head()
# Out:
# 1   2017-02-25
# 2   2017-05-21
# 3   2017-10-16
# 4   2017-08-31
# 5   2017-10-01
# Name: transaction_date, dtype: datetime64[ns]

# %%
df['transaction_date'].max()
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
df['transaction_date'].min()
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
df['transaction_date'].unique()
# Out:
# array(['2017-02-25T00:00:00.000000000', '2017-05-21T00:00:00.000000000',
#        '2017-10-16T00:00:00.000000000', '2017-08-31T00:00:00.000000000',
#        '2017-10-01T00:00:00.000000000', '2017-03-08T00:00:00.000000000',
#        '2017-04-21T00:00:00.000000000', '2017-07-15T00:00:00.000000000',
#        '2017-08-10T00:00:00.000000000', '2017-08-30T00:00:00.000000000',
#        '2017-01-17T00:00:00.000000000', '2017-01-05T00:00:00.000000000',
#        '2017-02-26T00:00:00.000000000', '2017-09-10T00:00:00.000000000',
#        '2017-06-11T00:00:00.000000000', '2017-10-10T00:00:00.000000000',
#        '2017-04-03T00:00:00.000000000', '2017-06-02T00:00:00.000000000',
#        '2017-04-06T00:00:00.000000000', '2017-01-28T00:00:00.000000000',
#        '2017-10-09T00:00:00.000000000', '2017-06-29T00:00:00.000000000',
#        '2017-04-08T00:00:00.000000000', '2017-10-18T00:00:00.000000000',
#        '2017-01-10T00:00:00.000000000', '2017-04-11T00:00:00.000000000',
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.tail(30)
# Out:
# 0     transaction_id product_id customer_id transaction_date online_order  \
# 19971        19971.0        1.0      1464.0       2017-03-18        False
# 19972        19972.0       46.0      2967.0       2017-05-10        False
# 19973        19973.0       39.0      1188.0       2017-05-13         True
# 19974        19974.0       80.0       148.0       2017-11-17         True
# 19975        19975.0       88.0      3129.0       2017-09-08         True
# 19976        19976.0       35.0      1700.0       2017-10-22        False
# 19977        19977.0       44.0      1102.0       2017-01-02        False
# 19978        19978.0       57.0       932.0       2017-10-08         True
# 19979        19979.0       27.0       333.0       2017-12-08         True
# 19980        19980.0       30.0      1435.0       2017-03-04         True
# 19981        19981.0       95.0      3304.0       2017-06-07        False
# 19982        19982.0       28.0      1075.0       2017-07-20         True
# ...

# %%
df.rename(columns={'product_first_sold_date':'product_first_sold_price'},inplace=True)

# %%
df.head()
# Out:
# 0 transaction_id product_id customer_id transaction_date online_order  \
# 1            1.0        2.0      2950.0       2017-02-25        False
# 2            2.0        3.0      3120.0       2017-05-21         True
# 3            3.0       37.0       402.0       2017-10-16        False
# 4            4.0       88.0      3135.0       2017-08-31        False
# 5            5.0       78.0       787.0       2017-10-01         True
#
# 0 order_status           brand product_line product_class product_size  \
# 1     Approved           Solex     Standard        medium       medium
# 2     Approved   Trek Bicycles     Standard        medium        large
# 3     Approved      OHM Cycles     Standard           low       medium
# 4     Approved  Norco Bicycles     Standard        medium       medium
# 5     Approved  Giant Bicycles     Standard        medium        large
#
# 0  list_price  standard_cost product_first_sold_price
# 1       71.49          53.62                  41245.0
# ...

# %%
df['product_first_sold_price']=df['product_first_sold_price'].astype('float')

# %%
df['online_order'].unique()
# Out:
# array([False, True, nan], dtype=object)

# %%
df['order_status'].unique()
# Out:
# array(['Approved', 'Cancelled'], dtype=object)

# %%
df['brand'].unique()
# Out:
# array(['Solex', 'Trek Bicycles', 'OHM Cycles', 'Norco Bicycles',
#        'Giant Bicycles', 'WeareA2B', nan], dtype=object)

# %%
df['product_line'].unique()
# Out:
# array(['Standard', 'Road', 'Mountain', 'Touring', nan], dtype=object)

# %%
df['product_class'].unique()
# Out:
# array(['medium', 'low', 'high', nan], dtype=object)

# %%
df['product_size'].unique()
# Out:
# array(['medium', 'large', 'small', nan], dtype=object)

# %%
df['transaction_date']=pd.to_datetime(df['transaction_date'])

# %%
df['transaction_date'].head()
# Out:
# 1   2017-02-25
# 2   2017-05-21
# 3   2017-10-16
# 4   2017-08-31
# 5   2017-10-01
# Name: transaction_date, dtype: datetime64[ns]

# %%
df.to_excel('Transaction_dataset')
