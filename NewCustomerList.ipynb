# %%
import pandas as pd

# %%
df=pd.read_excel('NewCustomerList.xlsx')

# %%
df.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                         first_name
# 1                                            Chickie
# 2                                              Morly
# 3                                            Ardelis
# 4                                             Lucine
#
#   Unnamed: 1 Unnamed: 2                           Unnamed: 3  \
# 0  last_name     gender  past_3_years_bike_related_purchases
# 1    Brister       Male                                   86
# 2     Genery       Male                                   69
# 3  Forrester     Female                                   10
# 4      Stutt     Female                                   64
#
#             Unnamed: 4                  Unnamed: 5             Unnamed: 6  \
# 0                  DOB                   job_title  job_industry_category
# ...

# %%
df.columns=df.iloc[0]#making header available

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1001 non-null   object
#  1   last_name                            972 non-null    object
#  2   gender                               1001 non-null   object
#  3   past_3_years_bike_related_purchases  1001 non-null   object
#  4   DOB                                  984 non-null    object
#  5   job_title                            895 non-null    object
#  6   job_industry_category                836 non-null    object
#  7   wealth_segment                       1001 non-null   object
#  8   deceased_indicator                   1001 non-null   object
#  9   owns_car                             1001 non-null   object
#  10  tenure                               1001 non-null   object
# ...

# %%
df.shape
# Out:
# (1001, 23)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(0,axis=0,inplace=True)#removing header like row

# %%
df.head()
# Out:
# 0 first_name  last_name  gender past_3_years_bike_related_purchases  \
# 1    Chickie    Brister    Male                                  86
# 2      Morly     Genery    Male                                  69
# 3    Ardelis  Forrester  Female                                  10
# 4     Lucine      Stutt  Female                                  64
# 5    Melinda     Hadlee  Female                                  34
#
# 0                  DOB                   job_title job_industry_category  \
# 1           1957-07-12             General Manager         Manufacturing
# 2           1970-03-22         Structural Engineer              Property
# 3  1974-08-28 00:00:00      Senior Cost Accountant    Financial Services
# 4           1979-01-28  Account Representative III         Manufacturing
# 5           1965-09-21           Financial Analyst    Financial Services
#
# 0     wealth_segment deceased_indicator owns_car  ... state    country  \
# ...

# %%
df.describe(include='object')
# Out:
# 0      first_name last_name  gender past_3_years_bike_related_purchases  \
# count        1000       971    1000                                1000
# unique        940       961       3                                 100
# top      Rozamond    Sissel  Female                                  60
# freq            3         2     513                                  20
#
# 0              DOB            job_title job_industry_category wealth_segment  \
# count          983                  894                   835           1000
# unique         961                  184                     9              3
# top     1965-07-03  Associate Professor    Financial Services  Mass Customer
# freq             2                   15                   203            508
#
# 0      deceased_indicator owns_car  tenure           address postcode state  \
# count                1000     1000  1000.0              1000     1000  1000
# ...

# %%
df['gender'].unique()
# Out:
# array(['Male', 'Female', 'U'], dtype=object)

# %%
import numpy as np
df['gender']=df['gender'].map({'Female':'F','Male':'M','U':np.nan})#making gender as F or M

# %%
df['state'].unique()
# Out:
# array(['QLD', 'NSW', 'VIC'], dtype=object)

# %%
df['deceased_indicator'].unique()
# Out:
# array(['N'], dtype=object)

# %%
df['owns_car'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['country'].unique()
# Out:
# array(['Australia'], dtype=object)

# %%
df['wealth_segment'].unique()
# Out:
# array(['Mass Customer', 'Affluent Customer', 'High Net Worth'],
#       dtype=object)

# %%
df['past_3_years_bike_related_purchases']=df['past_3_years_bike_related_purchases'].astype('float')

# %%
df['tenure']=df['tenure'].astype(float)

# %%
#changing from categorical to numeric

# %%
df.describe()
# Out:
# 0      past_3_years_bike_related_purchases       tenure          NaN  \
# count                          1000.000000  1000.000000  1000.000000
# mean                             49.836000    11.388000     0.753790
# std                              27.796686     5.037145     0.206523
# min                               0.000000     0.000000     0.400000
# 25%                              26.750000     7.000000     0.580000
# 50%                              51.000000    11.000000     0.760000
# 75%                              72.000000    15.000000     0.930000
# max                              99.000000    22.000000     1.100000
#
# 0              NaN          NaN          NaN          NaN
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.846115     0.951583     0.879323   498.819000
# std       0.250726     0.301963     0.289855   288.810997
# min       0.400000     0.400000     0.340000     1.000000
# ...

# %%
df['DOB']=pd.to_datetime(df['DOB'])

# %%
df['DOB'].max()
# Out:
# Timestamp('2002-02-27 00:00:00')

# %%
df['DOB'].min()
# Out:
# Timestamp('1938-06-08 00:00:00')

# %%
df['job_industry_category'].unique()
# Out:
# array(['Manufacturing', 'Property', 'Financial Services', 'Entertainment',
#        'Retail', 'IT', 'Telecommunications', 'Health', nan, 'Argiculture'],
#       dtype=object)

# %%
df=df.iloc[:,0:16]

# %%
df.head()
# Out:
# 0 first_name  last_name gender  past_3_years_bike_related_purchases  \
# 1    Chickie    Brister      M                                 86.0
# 2      Morly     Genery      M                                 69.0
# 3    Ardelis  Forrester      F                                 10.0
# 4     Lucine      Stutt      F                                 64.0
# 5    Melinda     Hadlee      F                                 34.0
#
# 0        DOB                   job_title job_industry_category  \
# 1 1957-07-12             General Manager         Manufacturing
# 2 1970-03-22         Structural Engineer              Property
# 3 1974-08-28      Senior Cost Accountant    Financial Services
# 4 1979-01-28  Account Representative III         Manufacturing
# 5 1965-09-21           Financial Analyst    Financial Services
#
# 0     wealth_segment deceased_indicator owns_car  tenure              address  \
# 1      Mass Customer                  N      Yes    14.0     45 Shopko Center
# ...

# %%
#removed columns not useful

# %%
df.reset_index()
# Out:
# 0    index first_name  last_name gender  past_3_years_bike_related_purchases  \
# 0        1    Chickie    Brister      M                                 86.0
# 1        2      Morly     Genery      M                                 69.0
# 2        3    Ardelis  Forrester      F                                 10.0
# 3        4     Lucine      Stutt      F                                 64.0
# 4        5    Melinda     Hadlee      F                                 34.0
# ..     ...        ...        ...    ...                                  ...
# 995    996  Ferdinand  Romanetti      M                                 60.0
# 996    997       Burk    Wortley      M                                 22.0
# 997    998   Melloney      Temby      F                                 17.0
# 998    999     Dickie    Cubbini      M                                 30.0
# 999   1000      Sylas    Duffill      M                                 56.0
#
# ...

# %%
df.to_excel('NewCustomerList.xlsx',index=False)
